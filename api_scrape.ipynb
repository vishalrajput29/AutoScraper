# %%
def get_j():

  url = "https://api.higherme.com/classic/jobs?page=1&includes=location,location.company,location.externalServiceReferences&limit=24&filters^[brand.id^]=58bd9e7f472bd"

  payload = {}
  headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:129.0) Gecko/20100101 Firefox/129.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'HigherMe-Client-Version': '2024.08.22_30.0d',
    'Origin': 'https://app.higherme.com',
    'Connection': 'keep-alive',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'TE': 'trailers'
  }

  response = requests.get(url, headers=headers, data=payload)

  return response.json()

# %%
response_data= get_j()

# %%
response_data
# Out:
# {'data': [{'id': '63',
#    'attributes': {'title': 'Logistics Associate',
#     'full_time': True,
#     'part_time': False,
#     'about': '',
#     'summary': "<p>The Logistics Associate will be a part of a team of logistics experts whose primary responsibilities are moving furniture in and out of our clients' homes, as well as around the warehouse.\r</p><p>\r</p><p>Individuals should be highly motivated, friendly, professional, and love working on a team. A Logistics Associate will also be a Brand Ambassador, as they are the face of Move Loot.\r</p><p>\r</p><p>It’s a tall order and we’re looking for folks up to the challenge! You will be our personal contact with buyers and sellers, and it’s extremely important you believe in what Move Loot is all about and are excited to help us grow while maintaining our core values.\r</p><p>\r</p><p>This is a fantastic opportunity for someone who wants to get in on the ground floor and grow with a young energetic company.</p>",
# ...

# %%
response =requests.get("https://api.higherme.com/classic/jobs?page=1&includes=location,location.company,location.externalServiceReferences&limit=24&filters^[brand.id^]=58bd9e7f472bd")

# %%
response.json()
# Out:
# {'data': [{'id': '63',
#    'attributes': {'title': 'Logistics Associate',
#     'full_time': True,
#     'part_time': False,
#     'about': '',
#     'summary': "<p>The Logistics Associate will be a part of a team of logistics experts whose primary responsibilities are moving furniture in and out of our clients' homes, as well as around the warehouse.\r</p><p>\r</p><p>Individuals should be highly motivated, friendly, professional, and love working on a team. A Logistics Associate will also be a Brand Ambassador, as they are the face of Move Loot.\r</p><p>\r</p><p>It’s a tall order and we’re looking for folks up to the challenge! You will be our personal contact with buyers and sellers, and it’s extremely important you believe in what Move Loot is all about and are excited to help us grow while maintaining our core values.\r</p><p>\r</p><p>This is a fantastic opportunity for someone who wants to get in on the ground floor and grow with a young energetic company.</p>",
# ...

# %%
import pandas as pd
import numpy as np

# %%
data = response.json()['data']
df = pd.DataFrame([item['attributes'] for item in data],
                  columns=['title','full_time']
                  )

# %%
df
# Out:
#                                             title  full_time
# 0                             Logistics Associate       True
# 1                                       Team Lead       True
# 2                                     Team Member       True
# 3                                 Delivery Driver      False
# 4                                         Manager       True
# 5                               Assistant Manager      False
# 6                        CiCi's Pizza Team Member       True
# 7   Part-time / Full-time Barista & Counter Staff       True
# 8                               Assistant Manager       True
# 9                                    Shift Leader       True
# 10                                  Store Manager       True
# 11                              Assistant Manager       True
# 12                 Member Services Representative      False
# 13                                   Club Manager       True
# ...
