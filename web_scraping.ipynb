# %%
from urllib.request import urlopen

# %%
url ="https://quotes.toscrape.com/"

# %%
response = urlopen(url)

# %%
response

# %%
response.status
# Out:
# 200

# %%
content = response.read()

# %%
content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.\xe2\x8
# ...

# %%
print(content.decode("utf-8")) #for proper content
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
#similar way
with urlopen(url) as response:
  content =response.read()
  print(content.decode("utf-8"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
# !pip install requests==2.31.0

# %%
import requests

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.\xe2\x8
# ...

# %%
print(content.decode("utf-8"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>\n        <
# ...

# %%
response.headers
# Out:
# {'Date': 'Sun, 10 Mar 2024 11:44:25 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '11054', 'Connection': 'keep-alive', 'Strict-Transport-Security': 'max-age=0; includeSubDomains; preload'}

# %%
response.headers['Content-Type']
# Out:
# 'text/html; charset=utf-8'

# %%
response = requests.get(url,headers={'User-Agent': 'Mozilla/5.0'})

# %%
response =requests.get("https://httpbin.org/headers")

# %%
response.json()
# Out:
# {'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-65ed9d1a-7fa3854249f768ef6bd32a50'}}

# %%
dict(response.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.31.0',
#  'Accept-Encoding': 'gzip, deflate',
#  'Accept': '*/*',
#  'Connection': 'keep-alive'}

# %%
url = "https://api.coinbase.com/v2/exchange-rates?currency=BTC"

# %%
import requests as r

# %%
r.get(url)
# Out:
# <Response [200]>

# %%
res=r.get(url)

# %%
res.json()
# Out:
# {'data': {'currency': 'BTC',
#   'rates': {'00': '662794.48931116389498984',
#    '1INCH': '112359.550561797752809',
#    'AAVE': '532.1979776476849388',
#    'ABT': '39958.254095543587628304',
#    'ACH': '2136900.597334967069223984',
#    'ACS': '18654914.492773001374745616',
#    'ADA': '95465.3937947494033413',
#    'AED': '256219.434500000002325304',
#    'AERGO': '391465.3198653198649284',
#    'AERO': '144538.046349725986500624',
#    'AFN': '5011055.930874399997674696',
#    'AGLD': '39977.718559271042086032',
#    'AIOZ': '97015.67345803490561208',
#    'ALCX': '1905.20606308889548728',
#    'ALEPH': '168337.644787644785732472',
#    'ALGO': '261437.9084967320261438',
#    'ALICE': '30596.105263157896450224',
#    'ALL': '6623072.02808187200165376',
#    'AMD': '28137646.107639743416272528',
#    'AMP': '13026913.165266106439398464',
#    'ANG': '125233.87427496',
#    'ANKR': '1398601.3986013986013986',
#    'ANT': '6996.4318197719163227',
#    'AOA': '58283744.76',
# ...

# %%
res.json()['data']['rates']['USD']
# Out:
# '69759.12'

# %%
#how to create own api
url ="https://api.sunrisesunset.io/json"

# %%
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36 Edg/122.0.0.0"
}

# %%
params = {
    "lat": 43.6531,
    "lng": -79.3832,
    "timezone": "EST",
    "date": "today"
}

# %%
res = r.get(url,params = params,headers = headers)

# %%
res.request.url
# Out:
# 'https://api.sunrisesunset.io/json?lat=43.6531&lng=-79.3832&timezone=EST&date=today'

# %%
res.request.headers
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36 Edg/122.0.0.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
res.status_code
# Out:
# 200

# %%
res.json()
# Out:
# {'results': {'date': '2024-03-10',
#   'sunrise': '6:41:04 AM',
#   'sunset': '6:17:40 PM',
#   'first_light': '5:05:40 AM',
#   'last_light': '7:53:03 PM',
#   'dawn': '6:12:27 AM',
#   'dusk': '6:46:16 PM',
#   'solar_noon': '12:29:22 PM',
#   'golden_hour': '5:39:27 PM',
#   'day_length': '11:36:36',
#   'timezone': 'EST',
#   'utc_offset': -300},
#  'status': 'OK'}

# %%
#into of authorization

# %%
API_KEY = "YOUR_API_KEY_HERE"

# %%
url = "https://api.exchange.coinbase.com/fils"

# %%
headers = {
    "Authorization":f"Bearer {API_KEY}",
    "Content-Type":"application/json"
}

# %%
r.get(url, headers = headers)
# Out:
# <Response [401]>

# %%
#basic auth->username,passward

# %%
auth = ("user1","pass2")

# %%
url = "https://www.httpbin.org/basic-auth/user1/pass2"

# %%
r.get(url,auth = auth)
# Out:
# <Response [200]>

# %%
#HTTPBin

# %%
r.delete("https://www.httpbin.org/delete").json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '0',
#   'Host': 'www.httpbin.org',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-65ed9d1d-7863e7886f6712651de2309b'},
#  'json': None,
#  'origin': '34.171.65.228',
#  'url': 'https://www.httpbin.org/delete'}

# %%
r.patch("https://www.httpbin.org/patch").json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '0',
#   'Host': 'www.httpbin.org',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-65ed9d1d-7fda2ac148dae3437f84780a'},
#  'json': None,
#  'origin': '34.171.65.228',
#  'url': 'https://www.httpbin.org/patch'}

# %%
r.put("https://www.httpbin.org/put").json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '0',
#   'Host': 'www.httpbin.org',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-65ed9d1d-28efe20264e01de00d0f2123'},
#  'json': None,
#  'origin': '34.171.65.228',
#  'url': 'https://www.httpbin.org/put'}

# %%
r.post("https://www.httpbin.org/post").json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '0',
#   'Host': 'www.httpbin.org',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-65ed9d1e-303c18de7dd18a5e6b1baf5d'},
#  'json': None,
#  'origin': '34.171.65.228',
#  'url': 'https://www.httpbin.org/post'}

# %%
#head= use for retrieve the headers without the body
#option= retieve the allows method for given resourse

# %%
# @title POSTING data

# %%
#client sends data to server via:
    #-headers
    #-query params
    #-body

# %%
resp = r.post("https://www.httpbin.org/post",data={"key1":"value1"})
resp.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key1': 'value1'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '11',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'www.httpbin.org',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-65ed9d1e-19aaeaa45f7fdfc83d494256'},
#  'json': None,
#  'origin': '34.171.65.228',
#  'url': 'https://www.httpbin.org/post'}

# %%
resp.request.body
# Out:
# 'key1=value1'

# %%
resp = r.post("https://www.httpbin.org/post",
              json={"key1":"value1"})
resp.json()
# Out:
# {'args': {},
#  'data': '{"key1": "value1"}',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '18',
#   'Content-Type': 'application/json',
#   'Host': 'www.httpbin.org',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-65ed9d1e-5c84330951bdfee05dddb5f1'},
#  'json': {'key1': 'value1'},
#  'origin': '34.171.65.228',
#  'url': 'https://www.httpbin.org/post'}

# %%
# @title beatifulsoap
import requests as r
res = r.get("https://books.toscrape.com/")

# %%
res.content
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" h
# ...

# %%
# !pip install beautifulsoup4==4.11.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 1.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.3
#     Uninstalling beautifulsoup4-4.12.3:
#       Successfully uninstalled beautifulsoup4-4.12.3
# ...

# %%
import requests as r
from bs4 import BeautifulSoup
res = r.get("https://books.toscrape.com/")

# %%
soup = BeautifulSoup(res.content,"html.parser") # also you can use lxml.parser

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.title
# Out:
# <title>
#     All products | Books to Scrape - Sandbox
# </title>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
#another method
soup.html
# Out:
# <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# <link href="static/oscar/css/styles.css" rel="stylesheet" type="text/css"/>
# <link href="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css" rel="stylesheet"/>
# <link href="static/oscar/css/datetimepicker.css" rel="stylesheet" type="text/css"/>
# </head>
# <body class="default" id="default">
# ...

# %%
soup.name
# Out:
# '[document]'

# %%
soup.h1 #by default return first h1 tag
# Out:
# <h1>All products</h1>

# %%
soup.div
# Out:
# <div class="page_inner">
# <div class="row">
# <div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>
# </div>
# </div>
# </div>

# %%
first_div = soup.div
type(first_div)
# Out:
# bs4.element.Tag

# %%
first_div.attrs #it gives only first class value
# Out:
# {'class': ['page_inner']}

# %%
first_div.div.div.attrs
# Out:
# {'class': ['col-sm-8', 'h1']}

# %%
first_div.attrs["class"].append("some-others-class") #add new class in div

# %%
first_div
# Out:
# <div class="page_inner some-others-class">
# <div class="row">
# <div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>
# </div>
# </div>
# </div>

# %%
# @title parent , children , descendants

# %%
soup.ul
# Out:
# <ul class="breadcrumb">
# <li>
# <a href="index.html">Home</a>
# </li>
# <li class="active">All products</li>
# </ul>

# %%
 print(soup.ul.prettify()) #here a is the child of li and li  is the child of ul
# Out:
# <ul class="breadcrumb">
#  <li>
#   <a href="index.html">
#    Home
#   </a>
#  </li>
#  <li class="active">
#   All products
#  </li>
# </ul>

# %%
soup.ul.children

# %%
list(soup.ul.children)
# Out:
# ['\n',
#  <li>
#  <a href="index.html">Home</a>
#  </li>,
#  '\n',
#  <li class="active">All products</li>,
#  '\n']

# %%
from bs4.element import NavigableString

# %%
list(filter(lambda x: type(x)!= NavigableString, soup.ul.children))
# Out:
# [<li>
#  <a href="index.html">Home</a>
#  </li>,
#  <li class="active">All products</li>]

# %%
def no_nav_strings(iterable):
  return list(filter(lambda x: type(x)!= NavigableString, soup.ul.children))

# %%
no_nav_strings(soup.ul.children)
# Out:
# [<li>
#  <a href="index.html">Home</a>
#  </li>,
#  <li class="active">All products</li>]

# %%
list(soup.ul.descendants)
# Out:
# ['\n',
#  <li>
#  <a href="index.html">Home</a>
#  </li>,
#  '\n',
#  <a href="index.html">Home</a>,
#  'Home',
#  '\n',
#  '\n',
#  <li class="active">All products</li>,
#  'All products',
#  '\n']

# %%
desc=no_nav_strings(soup.ul.descendants)

# %%
desc[0]
# Out:
# <li>
# <a href="index.html">Home</a>
# </li>

# %%
desc[0].parent
# Out:
# <ul class="breadcrumb">
# <li>
# <a href="index.html">Home</a>
# </li>
# <li class="active">All products</li>
# </ul>

# %%
# @title siblings

# %%
soup.ul.li
# Out:
# <li>
# <a href="index.html">Home</a>
# </li>

# %%
soup.ul.li.next_sibling
# Out:
# '\n'

# %%
soup.ul.li.next_sibling.next_sibling
# Out:
# <li class="active">All products</li>

# %%
soup.ul.li\
    .next_sibling\
    .next_sibling\
    .previous_sibling\
    .previous_sibling
# Out:
# <li>
# <a href="index.html">Home</a>
# </li>

# %%
# @title EXTRACTING TEXT

# %%
soup.a
# Out:
# <a href="index.html">Books to Scrape</a>

# %%
soup.a.get_text()
# Out:
# 'Books to Scrape'

# %%
soup.a.text
# Out:
# 'Books to Scrape'

# %%
soup.a.string
# Out:
# 'Books to Scrape'

# %%
soup.ul
# Out:
# <ul class="breadcrumb">
# <li>
# <a href="index.html">Home</a>
# </li>
# <li class="active">All products</li>
# </ul>

# %%
soup.ul.get_text()
# Out:
# '\n\nHome\n\nAll products\n'

# %%
soup.ul.text
# Out:
# '\n\nHome\n\nAll products\n'

# %%
soup.ul.string #because ul dont have string text string does not return parent child

# %%
print(soup.a.text,"of type", type(soup.a.text))
print(soup.a.get_text(),"of type", type(soup.a.get_text()))
print(soup.a.string,"of type", type(soup.a.string))
# Out:
# Books to Scrape of type <class 'str'>
# Books to Scrape of type <class 'str'>
# Books to Scrape of type <class 'bs4.element.NavigableString'>

# %%
soup.ul.get_text(separator=",")
# Out:
# '\n,\n,Home,\n,\n,All products,\n'

# %%
soup.ul.get_text(separator=",",strip = True)
# Out:
# 'Home,All products'

# %%
# @title EXTRACT ALL STRING

soup.stripped_strings
# Out:
# <generator object PageElement.stripped_strings at 0x7a1185722dc0>

# %%
all_strings = list(soup.stripped_strings)

# %%
all_strings
# Out:
# ['All products | Books to Scrape - Sandbox',
#  'Books to Scrape',
#  'We love being scraped!',
#  'Home',
#  'All products',
#  'Books',
#  'Travel',
#  'Mystery',
#  'Historical Fiction',
#  'Sequential Art',
#  'Classics',
#  'Philosophy',
#  'Romance',
#  'Womens Fiction',
#  'Fiction',
#  'Childrens',
#  'Religion',
#  'Nonfiction',
#  'Music',
#  'Default',
#  'Science Fiction',
#  'Sports and Games',
#  'Add a comment',
#  'Fantasy',
#  'New Adult',
#  'Young Adult',
#  'Science',
#  'Poetry',
#  'Paranormal',
#  'Art',
#  'Psychology',
#  'Autobiography',
#  'Parenting',
#  'Adult Fiction',
#  'Humor',
#  'Horror',
#  'History',
#  'Food and Drink',
#  'Christian Fiction',
#  'Business',
#  'Biography',
#  'Thriller',
#  'Contemporary',
#  'Spirituality',
#  'Academic',
#  'Self Help',
#  'Historical',
#  'Christian',
#  'Suspense',
#  'Short Stories',
#  'Novels',
#  'Health',
#  'Politics',
#  'Cultural',
#  'Erotica',
#  'Crime',
#  'All products',
#  '1000',
# ...

# %%
len(all_strings)
# Out:
# 147

# %%
len(list(soup.strings)) #len is huge it consist navagable string with white space
# Out:
# 852

# %%
list(soup.strings)[:10] #only one of them has essential text
# Out:
# ['\n',
#  '\n',
#  '\n',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  '\n',
#  '\n    All products | Books to Scrape - Sandbox\n',
#  '\n']

# %%
# @title SEARCH
#find()--> like find_all(), but return only 1st result
#find_all()

# %%
len(soup.find_all())
# Out:
# 541

# %%
#find all the anchor tag
soup.find_all("a")
# Out:
# [<a href="index.html">Books to Scrape</a>,
#  <a href="index.html">Home</a>,
#  <a href="catalogue/category/books_1/index.html">
#
#                                  Books
#
#                          </a>,
#  <a href="catalogue/category/books/travel_2/index.html">
#
#                                  Travel
#
#                          </a>,
#  <a href="catalogue/category/books/mystery_3/index.html">
#
#                                  Mystery
#
#                          </a>,
#  <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                  Historical Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                  Sequential Art
#
#                          </a>,
#  <a href="catalogue/category/books/classics_6/index.html">
#
#                                  Classics
#
#                          </a>,
# ...

# %%
len(soup.find_all("a"))
# Out:
# 94

# %%
#$all the anchor tag and paragraph tag
len(soup.find_all(["a", "p"]))
# Out:
# 154

# %%
#finding all the price tag in site
#  tag_name :p
#  attrs: class: price_color


price_tags=soup.find_all("p",attrs={"class":"price_color"})

# %%
[price.get_text() for price in price_tags]
# Out:
# ['£51.77',
#  '£53.74',
#  '£50.10',
#  '£47.82',
#  '£54.23',
#  '£22.65',
#  '£33.34',
#  '£17.93',
#  '£22.60',
#  '£52.15',
#  '£13.99',
#  '£20.66',
#  '£17.46',
#  '£52.29',
#  '£35.02',
#  '£57.25',
#  '£23.88',
#  '£37.59',
#  '£51.33',
#  '£45.17']

# %%
button_tags =soup.find_all("button",attrs={"class":"btn btn-primary btn-block"})

# %%
len(button_tags)
# Out:
# 20

# %%
soup.find_all("a",attrs={"title":"A Light in the Attic"})
# Out:
# [<a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>]

# %%
rating_tags = soup.find_all("p",attrs={"class":"star-rating Three"})

# %%
# @title Q1

# %%
import requests as r
from bs4 import BeautifulSoup

# %%
res = r.get("https://books.toscrape.com/")
soup = BeautifulSoup(res.content)

# %%
res.status_code
# Out:
# 200

# %%
len(soup.find_all())
# Out:
# 541

# %%
book_tags = soup.find_all("article", attrs = {"class":"product_pod"})

# %%
len(book_tags)
# Out:
# 20

# %%
def extract_book_data(book_tags):
  title = book_tags.find("h3").find("a")["title"]
  price = book_tags.find("p",attrs={"class":"price_color"}).get_text()
  rating = book_tags.find("p",attrs={"class":"star-rating"})["class"][-1]


  return title, price, rating

# %%
extract_book_data(book_tags[0])
# Out:
# ('A Light in the Attic', '£51.77', 'Three')

# %%
print(book_tags[0].prettify())
# Out:
# <article class="product_pod">
#  <div class="image_container">
#   <a href="catalogue/a-light-in-the-attic_1000/index.html">
#    <img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/>
#   </a>
#  </div>
#  <p class="star-rating Three">
#   <i class="icon-star">
#   </i>
#   <i class="icon-star">
#   </i>
#   <i class="icon-star">
#   </i>
#   <i class="icon-star">
#   </i>
#   <i class="icon-star">
#   </i>
#  </p>
#  <h3>
#   <a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">
#    A Light in the ...
#   </a>
#  </h3>
#  <div class="product_price">
#   <p class="price_color">
#    £51.77
#   </p>
#   <p class="instock availability">
#    <i class="icon-ok">
#    </i>
#    In stock
#   </p>
#   <form>
#    <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">
#     Add to basket
#    </button>
#   </form>
#  </div>
# </article>

# %%
#cleaning
def clean_price(price):
  return float("".join([char for char in price if char.isdigit() or char == "."]))

# %%
b = extract_book_data(book_tags[0])

# %%
type(clean_price(b[1]))
# Out:
# float

# %%
clean_price(b[1])
# Out:
# 51.77

# %%
#another cleaning method with regex
import re #regex
def clean_price(price):
  return float(re.sub("[^0-9.]", "",price))

# %%
clean_price(b[1])
# Out:
# 51.77

# %%
def map_rating(rating):
  rating_map = {
      "One":1,
      "Two":2,
      "Three":3,
      "Four":4,
      "Five":5
  }
  return rating_map[rating]

# %%
def extract_book_data(book_tags):
  title = book_tags.find("h3").find("a")["title"]
  price = book_tags.find("p",attrs={"class":"price_color"}).get_text()
  rating = book_tags.find("p",attrs={"class":"star-rating"})["class"][-1]


  return {
      "title":title,
      "price": clean_price(price),
      "rating":map_rating(rating)
  }

# %%
from random import choice

# %%
extract_book_data(choice(book_tags))
# Out:
# {'title': "It's Only the Himalayas", 'price': 45.17, 'rating': 2}

# %%
book_tags = soup.find_all("article",attrs = {"class":"product_pod"})
book_data = [extract_book_data(book_tag) for book_tag in book_tags]

# %%
book_data
# Out:
# [{'title': 'A Light in the Attic', 'price': 51.77, 'rating': 3},
#  {'title': 'Tipping the Velvet', 'price': 53.74, 'rating': 1},
#  {'title': 'Soumission', 'price': 50.1, 'rating': 1},
#  {'title': 'Sharp Objects', 'price': 47.82, 'rating': 4},
#  {'title': 'Sapiens: A Brief History of Humankind',
#   'price': 54.23,
#   'rating': 5},
#  {'title': 'The Requiem Red', 'price': 22.65, 'rating': 1},
#  {'title': 'The Dirty Little Secrets of Getting Your Dream Job',
#   'price': 33.34,
#   'rating': 4},
#  {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   'price': 17.93,
#   'rating': 3},
#  {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   'price': 22.6,
#   'rating': 4},
#  {'title': 'The Black Maria', 'price': 52.15, 'rating': 1},
#  {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)',
#   'price': 13.99,
#   'rating': 2},
# ...

# %%
# @title pandas

# %%
#average price
sum([book["price"] for book in book_data]) / len(book_data)
# Out:
# 38.048500000000004

# %%
[book["title"] for book in book_data if book["price"]<20]
# Out:
# ['The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#  'Starving Hearts (Triangular Trade Trilogy, #1)',
#  'Set Me Free']

# %%
# !pip install pandas==1.5.3

# %%
{...}
# Out:
# {Ellipsis}

# %%
import pandas as pd
df = pd.DataFrame(book_data)

# %%
df
# Out:
#                                                 title  price  rating
# 0                                A Light in the Attic  51.77       3
# 1                                  Tipping the Velvet  53.74       1
# 2                                          Soumission  50.10       1
# 3                                       Sharp Objects  47.82       4
# 4               Sapiens: A Brief History of Humankind  54.23       5
# 5                                     The Requiem Red  22.65       1
# 6   The Dirty Little Secrets of Getting Your Dream...  33.34       4
# 7   The Coming Woman: A Novel Based on the Life of...  17.93       3
# 8   The Boys in the Boat: Nine Americans and Their...  22.60       4
# 9                                     The Black Maria  52.15       1
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  13.99       2
# 11                              Shakespeare's Sonnets  20.66       4
# 12                                        Set Me Free  17.46       5
# ...

# %%
df.price.mean()
# Out:
# 38.048500000000004

# %%
df.head()
# Out:
#                                    title  price  rating
# 0                   A Light in the Attic  51.77       3
# 1                     Tipping the Velvet  53.74       1
# 2                             Soumission  50.10       1
# 3                          Sharp Objects  47.82       4
# 4  Sapiens: A Brief History of Humankind  54.23       5

# %%
df.tail()
# Out:
#                                                 title  price  rating
# 15  Our Band Could Be Your Life: Scenes from the A...  57.25       3
# 16                                               Olio  23.88       1
# 17  Mesaerion: The Best Science Fiction Stories 18...  37.59       1
# 18                       Libertarianism for Beginners  51.33       2
# 19                            It's Only the Himalayas  45.17       2

# %%
df.describe()
# Out:
#            price     rating
# count  20.000000  20.000000
# mean   38.048500   2.850000
# std    15.135231   1.565248
# min    13.990000   1.000000
# 25%    22.637500   1.000000
# 50%    41.380000   3.000000
# 75%    51.865000   4.000000
# max    57.250000   5.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['price'].plot(kind='hist', bins=20, title='price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rating'].plot(kind='hist', bins=20, title='rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
#you want to buy book whose price is less than 20
df[df.price < 20]
# Out:
#                                                 title  price  rating
# 7   The Coming Woman: A Novel Based on the Life of...  17.93       3
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  13.99       2
# 12                                        Set Me Free  17.46       5

# %%
#convert it to csv
df.to_csv("book.csv",index=False)

# %%
df.to_json('book.json',orient = "records")

# %%
# @title functional seach pattern

# %%
soup.find_all(id="messages")
# Out:
# [<div id="messages">
#  </div>]

# %%
len(soup.find_all(attrs={'id':lambda x:x is not None}))
# Out:
# 4

# %%
len(soup.find_all(id=lambda x:x is not None))
# Out:
# 4

# %%
def fiction_category_anchor(tag):
  return tag.name == "a" and "category" in tag["href"] and "Fiction" in tag.text

# %%
soup.find_all(fiction_category_anchor)
# Out:
# [<a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                  Historical Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/womens-fiction_9/index.html">
#
#                                  Womens Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/fiction_10/index.html">
#
#                                  Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/science-fiction_16/index.html">
#
#                                  Science Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/adult-fiction_29/index.html">
#
#                                  Adult Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/christian-fiction_34/index.html">
#
#                                  Christian Fiction
#
#                          </a>]

# %%
# @title text search

# %%
soup.find_all(text="Fiction")
# Out:
# []

# %%
import re

re.compile("Fiction",re.I)
# Out:
# re.compile(r'Fiction', re.IGNORECASE|re.UNICODE)

# %%
soup.find_all(text=re.compile("Fiction",re.I)) #I is ignore
# Out:
# ['\n                            \n                                Historical Fiction\n                            \n                        ',
#  '\n                            \n                                Womens Fiction\n                            \n                        ',
#  '\n                            \n                                Fiction\n                            \n                        ',
#  '\n                            \n                                Nonfiction\n                            \n                        ',
#  '\n                            \n                                Science Fiction\n                            \n                        ',
#  '\n                            \n                                Adult Fiction\n                            \n                        ',
#  '\n                            \n                                Christian Fiction\n                            \n                        ']

# %%
text_matches= soup.find_all(text=re.compile("Fiction",re.I))

# %%
[text.strip() for text in text_matches]
# Out:
# ['Historical Fiction',
#  'Womens Fiction',
#  'Fiction',
#  'Nonfiction',
#  'Science Fiction',
#  'Adult Fiction',
#  'Christian Fiction']

# %%
all_text =list(soup.stripped_strings)
[text for text in all_text if "fiction" in text.lower()]
# Out:
# ['Historical Fiction',
#  'Womens Fiction',
#  'Fiction',
#  'Nonfiction',
#  'Science Fiction',
#  'Adult Fiction',
#  'Christian Fiction']

# %%
soup.find_all("a",text=re.compile("Fiction",re.I))
# Out:
# [<a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                  Historical Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/womens-fiction_9/index.html">
#
#                                  Womens Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/fiction_10/index.html">
#
#                                  Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/nonfiction_13/index.html">
#
#                                  Nonfiction
#
#                          </a>,
#  <a href="catalogue/category/books/science-fiction_16/index.html">
#
#                                  Science Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/adult-fiction_29/index.html">
#
#                                  Adult Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/christian-fiction_34/index.html">
#
# ...

# %%
# @title search by css

# %%
title_tags = soup.select("article.product_pod > h3 > a")
titles = [tag["title"] for tag in title_tags]
titles
# Out:
# ['A Light in the Attic',
#  'Tipping the Velvet',
#  'Soumission',
#  'Sharp Objects',
#  'Sapiens: A Brief History of Humankind',
#  'The Requiem Red',
#  'The Dirty Little Secrets of Getting Your Dream Job',
#  'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#  'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#  'The Black Maria',
#  'Starving Hearts (Triangular Trade Trilogy, #1)',
#  "Shakespeare's Sonnets",
#  'Set Me Free',
#  "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#  'Rip it Up and Start Again',
#  'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#  'Olio',
#  'Mesaerion: The Best Science Fiction Stories 1800-1849',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas"]

# %%
soup.select("[title]")
# Out:
# [<a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>,
#  <a href="catalogue/tipping-the-velvet_999/index.html" title="Tipping the Velvet">Tipping the Velvet</a>,
#  <a href="catalogue/soumission_998/index.html" title="Soumission">Soumission</a>,
#  <a href="catalogue/sharp-objects_997/index.html" title="Sharp Objects">Sharp Objects</a>,
#  <a href="catalogue/sapiens-a-brief-history-of-humankind_996/index.html" title="Sapiens: A Brief History of Humankind">Sapiens: A Brief History ...</a>,
#  <a href="catalogue/the-requiem-red_995/index.html" title="The Requiem Red">The Requiem Red</a>,
#  <a href="catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html" title="The Dirty Little Secrets of Getting Your Dream Job">The Dirty Little Secrets ...</a>,
# ...

# %%
soup.select("[title*=Human]")
# Out:
# [<a href="catalogue/sapiens-a-brief-history-of-humankind_996/index.html" title="Sapiens: A Brief History of Humankind">Sapiens: A Brief History ...</a>]

# %%
soup.select("button.btn-primary[data-loading-text][class*=primary]")
# Out:
# [<button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
# ...

# %%
soup.select("button")
# Out:
# [<button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>,
# ...
